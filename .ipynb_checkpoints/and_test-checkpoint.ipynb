# %%
# %load_ext autoreload
# %autoreload 2

# %%
from priceanalytics.data import download_df_map, cache_df_map, load_cached_df_map 
from priceanalytics.plot import MultiPlot
from priceanalytics import indicators as I
from priceanalytics.backtest import Backtester

from datetime import datetime, date, time

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tickers = ['AAPL', 'MSFT']
raw_tdfs = download_df_map(tickers, interval=1)
# cache_df_map(raw_tdfs, _dir="cache")
# Out:
# raw AAPL: 25802 datapoints from 2023-09-25 to 2023-11-11
# raw MSFT: 22012 datapoints from 2023-09-25 to 2023-11-11

# %%
tdfs = load_cached_df_map(_dir="cache")

# for ticker, dfs in tdfs.items():
# #     for df in dfs:
#     df = dfs[0]
#     with MultiPlot(1) as m:
#     m.ohlc(df)

total = tdfs['AAPL'] + tdfs['MSFT']

for n, df in enumerate(total):
    
    _len = 10
    sig_len = 25
    
    df = I.add_andean_osc(df, _len=_len, sig_len=sig_len)
    df = df.iloc[_len:]

    # with MultiPlot(2, size=(40,20)) as m:
    #     m.ohlc(df)
    #     m.next()
    #     plt.plot(np.array(df['andean_bull']), color='#00ff00')
    #     plt.plot(np.array(df['andean_bear']), color='#ff0000')
    #     plt.plot(np.array(df['andean_signal']), color='#000000')
    
    ticker = 'AAPL' if n < len(tdfs['AAPL']) else 'MSFT'
    print('\nSAMPLE #', n, ' ', ticker)

    with Backtester(df, verbose=False) as b:
        for i, fr in b:
            if b.crossover("andean_bull", "andean_bear"):
                b.buy()
#                 print("buy @ $", b.at(i))

            elif b.crossover("andean_signal", "andean_bull"):
                b.sell()
#                 print("sell @ $", b.at(i))
#             b.sell()

        percent_ret = round(b.results(1) * 100, 2)
        print(f"returned {percent_ret}%")
        
#         with MultiPlot(2, size=(40,20)) as m:
#             m.ohlc(df)
#             m.next()
#             plt.plot(np.array(df['andean_bull']), color='#00ff00')
#             plt.plot(np.array(df['andean_bear']), color='#ff0000')
#             plt.plot(np.array(df['andean_signal']), color='#000000')
# Out:
# SAMPLE # 0   AAPL
# returned -0.11%
#
# SAMPLE # 1   AAPL
# returned -0.02%
#
# SAMPLE # 2   AAPL
# returned 0.2%
#
# SAMPLE # 3   AAPL
# returned -0.21%
#
# SAMPLE # 4   AAPL
# returned 0.22%
#
# SAMPLE # 5   AAPL
# returned -0.68%
#
# SAMPLE # 6   AAPL
# returned 0.09%
#
# SAMPLE # 7   AAPL
# returned 0.13%
#
# SAMPLE # 8   AAPL
# returned -0.09%
#
# SAMPLE # 9   AAPL
# returned -0.04%
#
# SAMPLE # 10   AAPL
# returned -0.48%
#
# SAMPLE # 11   AAPL
# returned 0.18%
#
# SAMPLE # 12   AAPL
# returned -0.51%
#
# SAMPLE # 13   AAPL
# returned -0.07%
#
# SAMPLE # 14   AAPL
# returned -0.05%
#
# SAMPLE # 15   AAPL
# returned 0.29%
#
# SAMPLE # 16   AAPL
# returned 0.43%
#
# SAMPLE # 17   AAPL
# returned 0.04%
#
# SAMPLE # 18   AAPL
# returned -0.02%
#
# SAMPLE # 19   AAPL
# returned 0.13%
#
# SAMPLE # 20   AAPL
# returned 0.01%
#
# SAMPLE # 21   AAPL
# returned 0.14%
#
# SAMPLE # 22   AAPL
# returned -0.09%
#
# SAMPLE # 23   AAPL
# returned -0.17%
#
# SAMPLE # 24   AAPL
# returned 0.19%
#
# SAMPLE # 25   AAPL
# returned -0.02%
#
# SAMPLE # 26   AAPL
# returned 0.02%
#
# SAMPLE # 27   AAPL
# returned 0.23%
#
# SAMPLE # 28   AAPL
# returned -0.25%
#
# SAMPLE # 29   AAPL
# returned 0.08%
#
# SAMPLE # 30   AAPL
# returned 0.13%
#
# SAMPLE # 31   AAPL
# returned 0.59%
#
# SAMPLE # 32   AAPL
# returned 0.12%
#
# SAMPLE # 33   AAPL
# returned 0.83%
#
# SAMPLE # 34   AAPL
# returned 0.34%
#
# SAMPLE # 35   MSFT
# returned -0.24%
#
# SAMPLE # 36   MSFT
# returned 0.45%
#
# SAMPLE # 37   MSFT
# returned 0.68%
#
# SAMPLE # 38   MSFT
# returned 0.36%
#
# SAMPLE # 39   MSFT
# returned 0.33%
#
# SAMPLE # 40   MSFT
# returned -0.2%
#
# SAMPLE # 41   MSFT
# returned -0.3%
#
# SAMPLE # 42   MSFT
# returned -0.26%
#
# SAMPLE # 43   MSFT
# returned 0.01%
#
# SAMPLE # 44   MSFT
# returned -0.05%
#
# SAMPLE # 45   MSFT
# returned -0.3%
#
# SAMPLE # 46   MSFT
# returned -0.34%
