# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %% [markdown]
# ## Download some sample data

# %%
import priceanalytics.data as data

big_df = data.alpaca_download_single(
    'AAPL',     
    past_days=30, 
    interval=1    
)
dfs = data.split_alpaca_on_day(big_df)

# %% [markdown]
# ## Square Bounds algorithm
#
# $$ \text{Opening and closing price series are defined by}\  O(t) \ \text{and} \ C(t) \ \text{respectively, while}\ \alpha\ \text{is an arbitrary constant.} $$
#
# $$ u(t) = \max( O(t),\ C(t),\ u(t-1) - \frac{u(t-1) - C(t)}{\alpha}  )$$
#
# $$ d(t) = \min( O(t),\ C(t),\ d(t-1) - \frac{C(t) - d(t-1)}{\alpha}  )$$
#
# $$ U(t) = \max( O(t)^2,\ C(t)^2,\ U(t-1)^2 - \frac{U(t-1) - C(t)^2}{\alpha}  )$$
#
# $$ D(t) = \min( O(t)^2,\ C(t)^2,\ D(t-1)^2 - \frac{C(t)^2 - D(t-1)}{\alpha}  )$$
#
# $$ B(t) = \sqrt{U(t)-u(t)^2} $$
#
# $$ b(t) = \sqrt{D(t)-d(t)^2} $$

# %%
import pandas as pd
import numpy as np

def sb(df, _len, sig_len):
    
    close = df['close'].to_numpy()
    _open = df['open'].to_numpy()

    N = len(close)
    alpha = 2 / (_len + 1)
    alpha_sig = 2 / (sig_len + 1)

    up1, up2, dn1, dn2, bull, bear, sig = np.zeros((7, N))

    up1[0] = dn1[0] = close[0]
    up2[0] = dn2[0] = close[0] ** 2

    #print(alpha, alpha_sig, up1[0], dn1[0], up2[0], dn2[0], sig[0])

    h = np.log
       
    for i in range(1, N):
        
        up1[i] = max(close[i], _open[i], up1[i - 1] - alpha * (up1[i - 1] - close[i]))
        dn1[i] = min(close[i], _open[i], dn1[i - 1] + alpha * (close[i] - dn1[i - 1]))

        up2[i] = max(close[i] ** 2, _open[i] ** 2, up2[i - 1] - alpha * (up2[i - 1] - close[i] ** 2))
        dn2[i] = min(close[i] ** 2, _open[i] ** 2, dn2[i - 1] + alpha * (close[i] ** 2 - dn2[i - 1]))
     
        #print(up1[i], np.sqrt(up2[i]), dn1[i], np.sqrt(dn2[i]))
        
        
        bull[i] = h(up2[i] - up1[i] ** 2)
        bear[i] = h(dn2[i] - dn1[i] ** 2)

        #sig[i] = sig[i - 1] + alpha_sig * (np.maximum(bull[i], bear[i]) - sig[i - 1])
        
    
    df['up1'] = up1.tolist()
    df['up2'] = np.sqrt(up2.tolist())
    
        
    df['dn1'] = dn1.tolist()
    df['dn2'] = np.sqrt(dn2.tolist())

    bull_1st_ddt = np.diff(bull)
    bull_2nd_ddt = np.diff(bull_1st_ddt)

    bear_1st_ddt = np.diff(bear)
    bear_2nd_ddt = np.diff(bear_1st_ddt)

    df['bull'] = bull.tolist()
    df['bear'] = bear.tolist()
    df['signal'] = sig.tolist()

    return df

# %%
import priceanalytics.plot as plot
import matplotlib.pyplot as plt


# Dear future self,
# learned: signal length has no affect on bull/bear lines
# things to do:
# - fuck around with it
# - ?????? cry ???????

def test_sb(df):
    _len = 20
    sig_len = 20
    df = sb(df, _len=_len, sig_len=sig_len)
    #df = df.iloc[_len:]
    
    
    
    with plot.MultiPlot(2, size=(18, 18)) as m:
        plt.plot(df['close'].to_numpy())
        
        plt.plot(df['up1'].to_numpy())
        #plt.plot(df['up2'].to_numpy())
        
        plt.plot(df['dn1'].to_numpy())
        #plt.plot(df['dn2'].to_numpy())


        m.next()
        plt.plot(df['bull'].to_numpy())
        plt.plot(df['bear'].to_numpy())
        plt.plot(df['signal'].to_numpy())


    

test_sb(dfs[-3].copy())
# Out:
# <ipython-input-99-6d7b9f696219>:33: RuntimeWarning: divide by zero encountered in log
#   bull[i] = h(up2[i] - up1[i] ** 2)
# <ipython-input-99-6d7b9f696219>:34: RuntimeWarning: divide by zero encountered in log
#   bear[i] = h(dn2[i] - dn1[i] ** 2)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:1448: RuntimeWarning: invalid value encountered in subtract
#   a = op(a[slice1], a[slice2])
